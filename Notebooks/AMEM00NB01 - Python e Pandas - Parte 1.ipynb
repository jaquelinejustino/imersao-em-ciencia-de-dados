# %% [markdown]
# # <center>VAI Academy</center>
# # <center> Introdução à Python e Pandas - Parte 1 </center>
# ___
# Todo o conteúdo que você terá acesso ao longo desse período é confidencial, não sendo possível compartilhar ou comercializar os links ou os materiais recebidos que sejam de propriedade da VAI Academy.
#
# Dessa forma, ao participar do curso você está aceitando os termos de confidencialidade e não-comercialização dos conteúdos que serão recebidos.
# ___
#
# # <center> Objetivos de aprendizado </center>
# - Familiarizar-se com o Jupyter Notebook
# - Ser capaz de interpretar e escrever um código básico em Python
# - Conhecer os tipos de dados do Python
# ___
#
# ## Conteúdo
# 1. [Introdução (Parte 1)](#intro)
# 2. [Python/Jupyter Básico (Partes 1 e 2)](#basics)
# 3. Python Datatypes (Parte 3)
# 4. Funções (Parte 4)
# 5. Numpy (Parte 5)
# 6. Pandas (Partes 6 e 7)
#
# <a id="intro"></a>
# ## 1. Introdução
#
# Olá! Esta é a parte 1 da primeira aula da **Capacitação em Ciência de Dados da VAI Academy, programa promovido pela Americanas S.A.**. O objetivo desta primeira aula é ser uma breve introdução sobre a importância da Ciência de Dados ("Data Science" em inglês) no mundo dos negócios e também a uma das ferramentas mais importantes para análise de dados: a linguagem de programação Python. Além disso, vamos falar de duas das mais importantes bibliotecas de Python para mexer com dados, o Numpy e o Pandas.
#
# Recomendamos que assistam os vídeos disponíveis no site do conteúdo da imersão, para saber mais sobre a utilização dos notebooks e sobre a introdução à Ciência de Dados antes de seguir com essa aula. O vídeo específico sobre essa aula também pode ser visto aqui mesmo nesse notebook, basta rodar (com ctrl+Enter) a célula abaixo que o vídeo aparecerá.
#
# O formato da aula permite que você acompanhe o material e faça os exercícios ao mesmo tempo. O  material necessário para a aula está presente nos notebooks, porém, colocamos algumas sugestões de conteúdo caso você tenha interesse em alguns assuntos mais específicos, explicitados através de links durante o material.
#
# Boa aula!

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('nrPzFSQXBHk', width=800, height=450)

# %% [markdown]
# #### 1.1. O uso da ciência de dados
#
# Os métodos de *machine learning* (em português: *aprendizado de máquina*, que será explicado mais a frente) vêm sendo bastante utilizados no mundo corporativo. Essa técnica utiliza algoritmos que processam grandes volumes de dados para identificar padrões de interesse e, assim, realizar previsões.
#
# Uma análise mais avançada dos dados permite identificar oportunidades de melhoria em uma companhia, tais como:
#
# - O armazenamento de dados do histórico de compras permite uma **comunicação mais efetiva e personalizada com o cliente**, proporcionando um melhor serviço ao consumidor
#
#
# - O uso de dados obtidos em redes sociais, e-commerce ou pesquisas auxiliam na percepção de como determinado produto está sendo utilizado e recebido pelo mercado consumidor, servindo como **feedback para futuros lançamentos**
#
#
# - A eficiência operacional de uma empresa pode ser totalmente transformada. A análise de dados pode ajudar na **melhoria dos processos de manufatura, distribuição, gestão de estoque, alocação de pessoas** e em diversas outras áreas.
#
#
# Vamos explicar na próxima seção o por quê do Python ser tão amado no mundo da ciência de dados, mas um dos motivos é que ele é bem simples de ler e escrever, similar ao inglês. Devido à sua simplicidade e fácil compreensão, o Python é bem indicado para iniciantes, e é por isso que essa foi a linguagem escolhida para este curso.

# %% [markdown]
# <a id="basics"></a>
# ## 2. Python/Jupyter Básico
#
# ### 2.1. O que é Python?
# Python é uma das [mais populares linguagens de programação do mundo](https://www.businessinsider.com/the-10-most-popular-programming-languages-according-to-github-2018-10). Se você quiser fazer um website ou colocar um modelo de *machine learning* em produção, o Python pode te levar lá! Abaixo estão listados alguns highlights da linguagem:
# - Linguagem de programação de uso geral (a linguagem pode ser utilizada para qualquer aplicação)
# - Open-source (seu uso é gratuito!)
# - Fácil de ler e escrever (Python possui uma sintaxe bem fácil! Além disso, sua comunidade é gigantesca, fazendo com que seja uma das linguagens mais fáceis de aprender!)
# - Uma das linguagens mais populares para Ciência de Dados
# - Uma das preferidas por cientistas da computação e desenvolvedores
# - Comumente utilizada para colocar modelos em produção
#
# ### 2.2. O que é Jupyter?
# "Jupyter" é um acrônimo que significa Julia, Python, and R. Essas linguagens de programação foram as primeiras utilizadas na aplicação Jupyter, mas, atualmente, o notebook também suporta  [muitas outras linguagens](https://github.com/jupyter/jupyter/wiki/Jupyter-kernels).
#
# Por se tratar de uma aplicação server-client, o Jupyter Notebook App permite ao usuário fazer a edição e execução de seus notebooks via web browser (Chrome, por exemplo). A aplicação pode ser executada em um PC sem acesso a Internet.
#
# - É possível executar um documento notebook step-by-step (uma célula por vez) pressionando shift + enter.
# - É possível executar todo o notebook em um único passo. Para isso, basta clicar no menu Cell -> Run All.
# - Para reiniciar o kernel (i.e., o engine), clique no menu Kernel -> Restart. Isso pode ser útil quando você quer reiniciar o processamento desde o começo (nesse caso, as variáveis são deletadas, arquivos abertos são fechados, etc...).
#
# **Keyboard Navigation**
#
# Essa interface do Jupyter Notebook foi **otimizada para uso eficiente do teclado**. Isso é possível porque há dois modos diferentes de atalhos com o teclado: modo de edição (edition mode) e modo de comando (command mode).
#
# Os atalhos mais importantes são **"Enter"**, que entra no **modo de edição**, e **"Esc"**, que entra no **modo de comando**.
#
# No modo de edição, a maior parte do teclado está disponível para digitar nas células do notebook. Por conta disso, neste modo não há muitos atalhos disponíveis. Para sair do modo de edição, você pode entrar no modo de comando (pressionando ```Esc```), ou pode executar a célula (pressionando ```Ctrl+Enter```). Já no modo de comando, o teclado inteiro pode ser utilizado para atalhos, portanto, existem muito mais atalhos. Se você clicar em *Help->Keyboard Shortcuts*, será possível ver toda a lista de atalhos disponível.
#
# Recomenda-se aprender os principais atalhos do modo de comando na seguinte ordem:
#
# Navegação básica:
# - ```Ctrl+Enter```: executa a célula
# - ```Shift+Enter```: executa a célula e seleciona a próxima célula
# - ```Up```/```k```: seleciona célula acima
# - ```Down```/```j```: seleciona célula abaixo
#
# Ações:
# - ```s```: salva o Notebook
# - ```y```, ```m```, ```1-6```: alterna o tipo da célula (code, markdown, títulos/subtítulos, respectivamente)
# - ```a```: cria uma célula acima da selecionada
# - ```b```: cria uma célula abaixo da selecionada
# - ```x```: recorta a célula
# - ```c```: copia a célula
# - ```v```: cola a célula abaixo da atual
# - ```d``` (pressionada rapidamente duas vezes): apaga a célula selecionada
# - ```z```: desfaz a ação de apagar a célula
# - ```l```: ativa a numeração das linhas
#
# Operações no kernel:
# - ```i``` (pressionada rapidamente duas vezes): interrompe o kernel
# - ```0``` (pressionada rapidamente duas vezes): reinicia o kernel
#
# Apesar de esses atalhos representarem o que você mais utilizará no cotidiano, existem algumas [dicas e macetes](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts) que podem melhorar sua experiência com a aplicação Jupyter Notebook.

# %% [markdown]
# ### 2.3. Como o Python funciona?
#
# Antes de começarmos a aprender a linguagem Python, é importante entender alguns conceitos comumente negligenciados de como o Python interpreta o texto (código) que nós escrevemos em um editor e o transforma em um programa executável. A imagem a seguir resume esses conceitos:
#
# ![Python Interpreter](https://i.imgur.com/PJME67T.png)
#
# Nós escrevemos [linhas de código](https://en.wikipedia.org/wiki/Source_lines_of_code) em um **código fonte** usando uma [linguagem de programação de alto nível](https://en.wikipedia.org/wiki/High-level_programming_language) que o computador não entende, mas que é fácil para nós utilizarmos. Após isso, o **compilador** traduz o código fonte em 0's e 1's, que nós chamamos de **byte-code**. A **Máquina Virtual (VM)** então executa as instruções contidas no [byte-code](https://pt.wikipedia.org/wiki/Bytecode), que gera um programa executável. Caso queira se aprofundar neste assunto, nós indicamos [esse vídeo](https://www.youtube.com/watch?v=aKoGwEPoQ5o).
#
# Agora que você já sabe um pouco como o Python funciona, vamos executar nossa primeira linha de código!

# %% [markdown]
# ### 2.4. Hello ~~World~~ Python!
# Não poderíamos começar a aprender Python sem utilizar o exemplo clássico [Hello World](https://en.wikipedia.org/wiki/%22Hello,_World!%22_program), né?
#
# Clique na célula abaixo e pressione ```Ctrl + Enter``` para executar o código.

# %%
print("Hello World!") #Lembre-se que shift+enter vai executar a célula atual e selecionar a próxima célula
# Out:
# Hello World!

# %% [markdown]
# Parabéns!!! Você acabou de executar sua primeira linha de código em Python. Foi bem fácil, né? A maioria dos exemplos das explicações virão em uma célula para você executar, então sempre que encontrar uma célula deste tipo no notebook, tente rodá-la!
#
# ![Easy](https://i.imgur.com/vTuKwWA.jpg "easy")
#
# Agora, para a linguagem Python, esse exemplo é, de fato, fácil, mas é bem importante, já que [muitas coisas mudaram do Python2 para o Python3](https://docs.python.org/3/whatsnew/index.html) e o comando *print* é uma delas.
#
# No **Python3**, que é a versão que estamos utilizando nessa aula, o comando *print* é uma função:

# %%
print ("print is a function")
# Out:
# print is a function

# %% [markdown]
# No **Python2**, entretanto, o comando *print* é um statement (então um erro é sinalizado):

# %%
print "print is a statement"
# Out:
#   Input In [4]
#     print "print is a statement"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("print is a statement")?

# %% [markdown]
# Agora vamos praticar e fazer nosso primeiro exercício.
#
# Como citado no início da aula, você pode realizar os exercícios neste próprio notebook, preenchendo a célula com o código que julgar correto, conforme requisitado. Observe abaixo:

# %% [markdown]
# #### Exercício 2.1

# %%
# Tente printar seu nome
print("Jaqueline")
# Out:
# Jaqueline

# %%
# Printe o motivo pelo qual você decidiu começar esse curso
print("Quero me tornar uma Cientista de Dados!")
# Out:
# Quero me tornar uma Cientista de Dados!

# %% [markdown]
# ### 2.5. Comentários
# Na maioria das linguagens de programação, se não todas, é possível adicionar comentários ao seu código. Comentários são muito importantes para garantir que outras pessoas (e, algumas vezes, até você mesmo) possam entender seu código sem, necessariamente, ter que interpretá-lo linha a linha. Comentários são peças chave na hora de debugar erros em códigos e não devem ser subestimados.
#
# Em Python, você pode usar o sinal "#" para adicionar comentários ao seu script. Esses comentários não serão executados e interpretados pelo Python, então, eles não irão influenciar no resultado do script!

# %%
print("Isso será printado.")  # print("Isso não será printado")
# Out:
# Isso será printado.

# %% [markdown]
# #### Exercício 2.2

# %%
#No código abaixo, comente o print que diz "Eu NÃO quero printar isso!"
print("Eu quero printar isso!")
print("Eu NÃO quero printar isso!") #print("Eu NÃO quero printar isso!")
# Out:
# Eu quero printar isso!
# Eu NÃO quero printar isso!

# %% [markdown]
# ### 2.6. Python como calculadora  - Operações básicas
#
# #### 2.6.1 Operações Matemáticas
# Através do Python é perfeitamente possível realizar cálculos básicos. Mas além das operações de adição, subtração, multiplicação e divisão, também é possível fazer operações matemáticas mais avançadas, como por exemplo:
#
# - **Exponenciação** (\*\*): Esse operador eleva o número da esquerda (base) ao número da direita (expoente). Por exemplo, 4\*\*2 resultará 16.
# - **Módulo** (%): Esse operador retorna o resto da divisão do número da esquerda pelo número da direita. Por exemplo, 18 % 7 é igual a 4.

# %%
# Adição
print(7 + 5)
# Out:
# 12

# %%
# Subtração
print(7 - 5)
# Out:
# 2

# %%
# Multiplicação
print(7 * 5)
# Out:
# 35

# %%
# Divisão
print(7 / 5)
# Out:
# 1.4

# %%
# Módulo
print(7 % 5)
# Out:
# 2

# %%
# Exponenciação
print(7 ** 5)
# Out:
# 16807

# %% [markdown]
# #### Exercício 2.3
# Suponha que você tenha \$100 e que você queira investir esse montante com uma taxa de retorno de 10\% ao ano. Após um ano, você terá 100×1.1=110 reais. Após dois anos, você terá 100×1.1×1.1=121 reais. Substitua o ```____``` na célula abaixo pela expressão que faz o cálculo do quanto de capital você terá com esse investimento **após 25 anos**. Não se preocupe com a sintaxe (a parte ```resposta_2_3 =```), explicaremos o que é isso em breve. Basta escrever a expressão da mesma forma que você faria dentro de um ```print```

# %%
#Escreva sua resposta aqui
resposta_2_3 = 100*(1.1**25)
print(resposta_2_3)

# Dica: você pode resolver o problema utilizando apenas multiplicações, ou utilizando multiplicação e 
# exponenciação. Qual forma você considera mais fácil?
# Out:
# 1083.4705943388394

# %% [markdown]
# #### 2.6.2 Operações lógicas (booleana)
# Python também suporta operadores lógicos e eles são realmente úteis quando estamos lidando com testes condicionais no código (não se preocupe, iremos explicar esse tópico mais pra frente). Essas operações lógicas retornam apenas resultados lógicos (booleanos) e elas podem ser classificadas nas seguintes categorias:
#
# **Comparações**
#
# Como o próprio nome sugere, essas operações comparam dois objetos e são muito úteis para determinar o comportamento do seu código em vários cenários (são muito úteis para executar o código bloco a bloco e entender se ele está fazendo o que é esperado).

# %%
#Igual [==]. O operador == compara os VALORES dos operandos e checa a igualdade de VALORES
print(10 == 10)
print("Hi" == "Hello")
print (10.0 == 10) #Por que essa operação retorna verdadeiro? Porque o operador == compara VALORES e não TIPOS
# Out:
# True
# False
# True

# %%
#Maior [>] (ou igual [>=]) que
print(5 > 3)
print(5.0 > 5)
# Out:
# True
# False

# %%
#Menor [<] (ou igual [<=]) que
print(5 < 3)
print("bcdefghyjklmnopqrstuvwxyz" < "a") #Por que essa operação retorna falso? Porque o Python compara strings char por char!
# Out:
# False
# False

# %%
#Diferente de [!=]
print("Hi" != "Bye")
print ("CASE SENSITIVE" != "Case Sensitive")
# Out:
# True
# True

# %% [markdown]
# #### Exercício 2.4
# Tente adivinhar o output das seguintes comparações. Comente seus palpites e execute o código para ver se você estava certo! *Lembre-se que essas operações retornam apenas valores lógicos, i.e., True ou False*

# %%
print(5 <= 5) #Seu palpite é: True
# Out:
# True

# %%
print("HI" == "Hi") #Seu palpite é: False
# Out:
# False

# %%
print(5 == (10/2.0)) #Seu palpite é: True
# Out:
# True

# %%
print(5.0 != 5) #Seu palpite é: False
# Out:
# False

# %%
print("Hello" > "Hi") #Seu palpite é: False
# Out:
# False

# %%
print("5.0" > "5") #Seu palpite é: True
# Out:
# True

# %% [markdown]
# **Bitwise**
#
# Basicamente essas operações funcionam similarmente aos clássicos AND, OR, NOT, etc. Elas são chamadas de bitwise porque executam a operação bit a bit!

# %%
# AND (&)
print(False & False)
print(True & True)
print(True & True & True & True & False & True & True & True  & True)
# Out:
# False
# True
# False

# %%
# OR (|)
print(True | False)
print(False | False)
print(False | False & False | True | False | False | False | False | False)
# Out:
# True
# False
# True

# %%
# NOT (~)
print(bool(~False)) #bool() converte o tipo de um dado objeto em booleano. Nós iremos falar sobre isso mais tarde!
# Out:
# True

# %%
#XOR (^). (eXclusive OR)
print(False ^ (False ^ True))
print(False ^ False ^ True)
print(False ^ True ^ False ^ False ^ False)
print(True ^ True ^ False) 
print(False ^ True ^ False & True)
print(False ^ True ^ False | True)

# Dica: pesquise sobre a precedência dos operadores quando estiver lidando com vários operadores para saber a ordem que o Python resolve as expressões
# Out:
# True
# True
# True
# False
# True
# True

# %% [markdown]
# #### Exercício 2.5
# Tente adivinhar o output das seguintes comparações. Comente seus palpites e execute o código para ver se você estava certo! *Lembre-se que essas operações retornam apenas valore lógicos, i.e., True ou False*

# %%
print(False | False) #Seu palpite é: False
# Out:
# False

# %%
print(True & False) #Seu palpite é: False
# Out:
# False

# %%
#Dica: Python trata zero como False e todos os outros números são True (positivos ou negativos)
print(bool(5 & 0)) #Seu palpite é: False
# Out:
# False

# %%
print(bool(5 & 1)) #Seu palpite é: True
# Out:
# True

# %%
print(bool(5 | -1)) #Seu palpite é: True
# Out:
# True

# %% [markdown]
# **Pertence a**
#
# Essa operação verifica se um objeto está dentro/contido de algum outro objeto. Para fazer isso, você deve usar os operadores **in** e **not in**. Veja:

# %%
#Pertence a
print("The force is with" in "me")
print("The force is" not in "with me")
# Out:
# False
# True

# %% [markdown]
# #### Exercício 2.6
# Tente adivinhar o output das seguintes comparações. Comente seus palpites e execute o código para ver se você estava certo! *Lembre-se que essas operações retornam apenas valores lógicos, i.e., True ou False*

# %%
print("Hello" in "Hello") #Seu palpite é: True
# Out:
# True

# %%
print("HELLO" in "Hello") #Seu palpite é: False
# Out:
# False

# %%
print("Hello" not in "darkness my old friend") #Seu palpite é: True
# Out:
# True

# %%
print("5" in "25") #Seu palpite é: True
# Out:
# True

# %%
print("5.0" in "5") #Seu palpite é: False
# Out:
# False

# %%
print ("This is a test" not in "This is not a test") #Seu palpite é: True
# Out:
# True

# %% [markdown]
# # Declaração de Inexistência de Plágio:
#
# 1. Eu sei que plágio é utilizar o trabalho de outra pessoa e apresentar como meu.
# 2. Eu sei que plágio é errado e declaro que este notebook foi feito por mim.
# 3. Tenho consciência de que a utilização do trabalho de terceiros é antiético e está sujeito à medidas administrativas.
# 4. Declaro também que não compartilhei e não compartilharei meu trabalho com o intuito de que seja copiado e submetido por outra pessoa.

# %%
# LEMBRE-SE DE SALVAR O NOTEBOOK ANTES DE EXECUTAR ESSA CELULA
token = '___' # seu token aqui

# Não altere o código abaixo
import requests as req
exec(req.get('https://api.vai.academy/submissioncode2').text)

# %% [markdown]
# ## Fim da primeira parte da aula!

# %% [markdown]
# Parabéns por finalizar o notebook! Agora você já sabe o básico de Python e pode prosseguir para a segunda parte, onde você vai aprender a criar suas próprias funções, como no exemplo acima!
